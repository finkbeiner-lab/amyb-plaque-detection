# %%
import pandas as pd
import numpy as np
from glob import glob
import os
import json
from PIL import Image
import albumentations as A
import random
import os
from os.path import exists
import glob
import json
import shutil

# %%
path = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/amy-def-mfg-jsons"

# %%
val_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/amy-def-mfg-test-jsons"

# %%
df = pd.DataFrame({"json_path":glob.glob(os.path.join(path,"*.json"))})

# %%
val_df = pd.DataFrame({"json_path":glob.glob(os.path.join(val_path,"*.json"))})

# %%
def get_count(l):
    with open(l) as f:
        data = json.load(f)
    plaque_dict = {'Cored': 0, 'Diffuse': 0, 'Coarse-Grained': 0,'CAA': 0}
    for tileId, ele in data.items():
        for region in ele:
            if "label" in region.keys():
                if "name" in region['label'].keys():
                    plaque_dict[region['label']["name"]]=plaque_dict[region['label']["name"]]+1
    return plaque_dict

# %%
for cls in ["Cored","Diffuse","Coarse-Grained","CAA"]:
    df[cls] = df["json_path"].apply(lambda l:get_count(l)[cls] )

# %%
for cls in ["Cored","Diffuse","Coarse-Grained","CAA"]:
    val_df[cls] = val_df["json_path"].apply(lambda l:get_count(l)[cls] )

# %%
df["file_name"] = df["json_path"].apply(lambda l: l.split("/")[-1].split(".")[0])

# %%
val_df["file_name"] = val_df["json_path"].apply(lambda l: l.split("/")[-1].split(".")[0])

# %%
df
# Out:
#                                             json_path  Cored  Diffuse  \
# 0   /gladstone/finkbeiner/steve/work/data/npsad_da...     21       26
# 1   /gladstone/finkbeiner/steve/work/data/npsad_da...      5       34
# 2   /gladstone/finkbeiner/steve/work/data/npsad_da...     13       18
# 3   /gladstone/finkbeiner/steve/work/data/npsad_da...      2       27
# 4   /gladstone/finkbeiner/steve/work/data/npsad_da...     23       22
# 5   /gladstone/finkbeiner/steve/work/data/npsad_da...      1       20
# 6   /gladstone/finkbeiner/steve/work/data/npsad_da...     10       13
# 7   /gladstone/finkbeiner/steve/work/data/npsad_da...     27       97
# 8   /gladstone/finkbeiner/steve/work/data/npsad_da...     26       27
# 9   /gladstone/finkbeiner/steve/work/data/npsad_da...      6       20
# 10  /gladstone/finkbeiner/steve/work/data/npsad_da...     13       13
# 11  /gladstone/finkbeiner/steve/work/data/npsad_da...     43        7
# 12  /gladstone/finkbeiner/steve/work/data/npsad_da...      9        5
# 13  /gladstone/finkbeiner/steve/work/data/npsad_da...     10       28
# 14  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        0
# 15  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       27
# 16  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       26
# 17  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       14
#
#     Coarse-Grained  CAA          file_name
# 0                3    0  XE07-047_1_AmyB_1
# 1                3    0  XE18-066_1_AmyB_1
# 2                4    8  XE07-064_1_AmyB_1
# 3                3    9  XE17-004_1_AmyB_1
# 4               14    0  XE15-039_1_AmyB_1
# 5                0    2  XE19-037_1_AmyB_1
# 6               10    9  XE17-039_1_AmyB_1
# 7                5    0  XE07-048_1_AmyB_1
# 8                6    6  XE15-022_1_AmyB_1
# 9               10    6  XE10-045_1_AmyB_1
# 10               7    4  XE19-028_1_AmyB_1
# 11              27    0  XE19-010_1_AmyB_1
# 12              16    5  XE11-039_1_AmyB_1
# 13               4    1  XE12-016_1_AmyB_1
# 14               0    0  XE18-003_1_AmyB_1
# 15               0    1  XE11-025_1_AmyB_1
# 16               3    8  XE07-049_1_AmyB_1
# 17               5    1  XE10-053_1_AmyB_1

# %%
val_df["flag"]="train"

# %%
test_files =  [x.split("/")[-1] for x in glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test","*"))]

# %%
df["flag"] = df["file_name"].apply(lambda l: "test" if l in test_files else "val")

# %%
df
# Out:
#                                             json_path  Cored  Diffuse  \
# 0   /gladstone/finkbeiner/steve/work/data/npsad_da...     21       26
# 1   /gladstone/finkbeiner/steve/work/data/npsad_da...      5       34
# 2   /gladstone/finkbeiner/steve/work/data/npsad_da...     13       18
# 3   /gladstone/finkbeiner/steve/work/data/npsad_da...      2       27
# 4   /gladstone/finkbeiner/steve/work/data/npsad_da...     23       22
# 5   /gladstone/finkbeiner/steve/work/data/npsad_da...      1       20
# 6   /gladstone/finkbeiner/steve/work/data/npsad_da...     10       13
# 7   /gladstone/finkbeiner/steve/work/data/npsad_da...     27       97
# 8   /gladstone/finkbeiner/steve/work/data/npsad_da...     26       27
# 9   /gladstone/finkbeiner/steve/work/data/npsad_da...      6       20
# 10  /gladstone/finkbeiner/steve/work/data/npsad_da...     13       13
# 11  /gladstone/finkbeiner/steve/work/data/npsad_da...     43        7
# 12  /gladstone/finkbeiner/steve/work/data/npsad_da...      9        5
# 13  /gladstone/finkbeiner/steve/work/data/npsad_da...     10       28
# 14  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        0
# 15  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       27
# 16  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       26
# 17  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       14
#
#     Coarse-Grained  CAA          file_name  flag
# 0                3    0  XE07-047_1_AmyB_1   val
# 1                3    0  XE18-066_1_AmyB_1  test
# 2                4    8  XE07-064_1_AmyB_1   val
# 3                3    9  XE17-004_1_AmyB_1   val
# 4               14    0  XE15-039_1_AmyB_1   val
# 5                0    2  XE19-037_1_AmyB_1  test
# 6               10    9  XE17-039_1_AmyB_1   val
# 7                5    0  XE07-048_1_AmyB_1   val
# 8                6    6  XE15-022_1_AmyB_1   val
# 9               10    6  XE10-045_1_AmyB_1   val
# 10               7    4  XE19-028_1_AmyB_1   val
# 11              27    0  XE19-010_1_AmyB_1   val
# 12              16    5  XE11-039_1_AmyB_1  test
# 13               4    1  XE12-016_1_AmyB_1   val
# 14               0    0  XE18-003_1_AmyB_1  test
# 15               0    1  XE11-025_1_AmyB_1   val
# 16               3    8  XE07-049_1_AmyB_1  test
# 17               5    1  XE10-053_1_AmyB_1   val

# %%
test_files
# Out:
# ['XE19-037_1_AmyB_1',
#  'XE18-003_1_AmyB_1',
#  'XE11-039_1_AmyB_1',
#  'XE07-049_1_AmyB_1',
#  'XE18-066_1_AmyB_1']

# %%
df1 = pd.concat([df,val_df], ignore_index=True)

# %%
df1
# Out:
#                                             json_path  Cored  Diffuse  \
# 0   /gladstone/finkbeiner/steve/work/data/npsad_da...     21       26
# 1   /gladstone/finkbeiner/steve/work/data/npsad_da...      5       34
# 2   /gladstone/finkbeiner/steve/work/data/npsad_da...     13       18
# 3   /gladstone/finkbeiner/steve/work/data/npsad_da...      2       27
# 4   /gladstone/finkbeiner/steve/work/data/npsad_da...     23       22
# 5   /gladstone/finkbeiner/steve/work/data/npsad_da...      1       20
# 6   /gladstone/finkbeiner/steve/work/data/npsad_da...     10       13
# 7   /gladstone/finkbeiner/steve/work/data/npsad_da...     27       97
# 8   /gladstone/finkbeiner/steve/work/data/npsad_da...     26       27
# 9   /gladstone/finkbeiner/steve/work/data/npsad_da...      6       20
# 10  /gladstone/finkbeiner/steve/work/data/npsad_da...     13       13
# 11  /gladstone/finkbeiner/steve/work/data/npsad_da...     43        7
# 12  /gladstone/finkbeiner/steve/work/data/npsad_da...      9        5
# 13  /gladstone/finkbeiner/steve/work/data/npsad_da...     10       28
# 14  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        0
# 15  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       27
# 16  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       26
# 17  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       14
# 18  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        6
# 19  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       13
# 20  /gladstone/finkbeiner/steve/work/data/npsad_da...      7        7
# 21  /gladstone/finkbeiner/steve/work/data/npsad_da...     14        3
# 22  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       13
# 23  /gladstone/finkbeiner/steve/work/data/npsad_da...     10       29
# 24  /gladstone/finkbeiner/steve/work/data/npsad_da...      1        2
# 25  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        0
# 26  /gladstone/finkbeiner/steve/work/data/npsad_da...     22       34
# 27  /gladstone/finkbeiner/steve/work/data/npsad_da...     25       23
#
#     Coarse-Grained  CAA          file_name   flag
# 0                3    0  XE07-047_1_AmyB_1    val
# 1                3    0  XE18-066_1_AmyB_1   test
# 2                4    8  XE07-064_1_AmyB_1    val
# 3                3    9  XE17-004_1_AmyB_1    val
# 4               14    0  XE15-039_1_AmyB_1    val
# 5                0    2  XE19-037_1_AmyB_1   test
# 6               10    9  XE17-039_1_AmyB_1    val
# 7                5    0  XE07-048_1_AmyB_1    val
# 8                6    6  XE15-022_1_AmyB_1    val
# 9               10    6  XE10-045_1_AmyB_1    val
# 10               7    4  XE19-028_1_AmyB_1    val
# 11              27    0  XE19-010_1_AmyB_1    val
# 12              16    5  XE11-039_1_AmyB_1   test
# 13               4    1  XE12-016_1_AmyB_1    val
# 14               0    0  XE18-003_1_AmyB_1   test
# 15               0    1  XE11-025_1_AmyB_1    val
# 16               3    8  XE07-049_1_AmyB_1   test
# 17               5    1  XE10-053_1_AmyB_1    val
# 18              22    0  XE14-004_1_AmyB_1  train
# 19               9    0  XE17-010_1_AmyB_1  train
# 20              10    0  XE17-030_1_AmyB_1  train
# 21              17    4  XE17-059_1_AmyB_1  train
# 22              10    9  XE16-021_1_AmyB_1  train
# 23              25    0  XE09-063_1_AmyB_1  train
# 24               4    0  XE18-001_1_AmyB_1  train
# 25               2    0  XE18-004_1_AmyB_1  train
# 26               4    0  XE13-007_1_AmyB_1  train
# 27               2   21  XE12-010_1_AmyB_1  train

# %%
train_list2 = ["XE07-064_1_AmyB_1","XE17-039_1_AmyB_1","XE10-045_1_AmyB_1","XE12-016_1_AmyB_1","XE15-022_1_AmyB_1","XE15-039_1_AmyB_1"]

# %%
df1["flag"]=np.where(df1["file_name"].isin(train_list2), "train",df1["flag"] )

# %%
df1.groupby(["flag"]).sum()
# Out:
#        Cored  Diffuse  Coarse-Grained  CAA
# flag
# test      26       85              22   15
# train    183      258             153   64
# val      119      211              50   15

# %%
df1
# Out:
#                                             json_path  Cored  Diffuse  \
# 0   /gladstone/finkbeiner/steve/work/data/npsad_da...     21       26
# 1   /gladstone/finkbeiner/steve/work/data/npsad_da...      5       34
# 2   /gladstone/finkbeiner/steve/work/data/npsad_da...     13       18
# 3   /gladstone/finkbeiner/steve/work/data/npsad_da...      2       27
# 4   /gladstone/finkbeiner/steve/work/data/npsad_da...     23       22
# 5   /gladstone/finkbeiner/steve/work/data/npsad_da...      1       20
# 6   /gladstone/finkbeiner/steve/work/data/npsad_da...     10       13
# 7   /gladstone/finkbeiner/steve/work/data/npsad_da...     27       97
# 8   /gladstone/finkbeiner/steve/work/data/npsad_da...     26       27
# 9   /gladstone/finkbeiner/steve/work/data/npsad_da...      6       20
# 10  /gladstone/finkbeiner/steve/work/data/npsad_da...     13       13
# 11  /gladstone/finkbeiner/steve/work/data/npsad_da...     43        7
# 12  /gladstone/finkbeiner/steve/work/data/npsad_da...      9        5
# 13  /gladstone/finkbeiner/steve/work/data/npsad_da...     10       28
# 14  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        0
# 15  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       27
# 16  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       26
# 17  /gladstone/finkbeiner/steve/work/data/npsad_da...      8       14
# 18  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        6
# 19  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       13
# 20  /gladstone/finkbeiner/steve/work/data/npsad_da...      7        7
# 21  /gladstone/finkbeiner/steve/work/data/npsad_da...     14        3
# 22  /gladstone/finkbeiner/steve/work/data/npsad_da...      5       13
# 23  /gladstone/finkbeiner/steve/work/data/npsad_da...     10       29
# 24  /gladstone/finkbeiner/steve/work/data/npsad_da...      1        2
# 25  /gladstone/finkbeiner/steve/work/data/npsad_da...      3        0
# 26  /gladstone/finkbeiner/steve/work/data/npsad_da...     22       34
# 27  /gladstone/finkbeiner/steve/work/data/npsad_da...     25       23
#
#     Coarse-Grained  CAA          file_name   flag
# 0                3    0  XE07-047_1_AmyB_1    val
# 1                3    0  XE18-066_1_AmyB_1   test
# 2                4    8  XE07-064_1_AmyB_1  train
# 3                3    9  XE17-004_1_AmyB_1    val
# 4               14    0  XE15-039_1_AmyB_1  train
# 5                0    2  XE19-037_1_AmyB_1   test
# 6               10    9  XE17-039_1_AmyB_1  train
# 7                5    0  XE07-048_1_AmyB_1    val
# 8                6    6  XE15-022_1_AmyB_1  train
# 9               10    6  XE10-045_1_AmyB_1  train
# 10               7    4  XE19-028_1_AmyB_1    val
# 11              27    0  XE19-010_1_AmyB_1    val
# 12              16    5  XE11-039_1_AmyB_1   test
# 13               4    1  XE12-016_1_AmyB_1  train
# 14               0    0  XE18-003_1_AmyB_1   test
# 15               0    1  XE11-025_1_AmyB_1    val
# 16               3    8  XE07-049_1_AmyB_1   test
# 17               5    1  XE10-053_1_AmyB_1    val
# 18              22    0  XE14-004_1_AmyB_1  train
# 19               9    0  XE17-010_1_AmyB_1  train
# 20              10    0  XE17-030_1_AmyB_1  train
# 21              17    4  XE17-059_1_AmyB_1  train
# 22              10    9  XE16-021_1_AmyB_1  train
# 23              25    0  XE09-063_1_AmyB_1  train
# 24               4    0  XE18-001_1_AmyB_1  train
# 25               2    0  XE18-004_1_AmyB_1  train
# 26               4    0  XE13-007_1_AmyB_1  train
# 27               2   21  XE12-010_1_AmyB_1  train

# %% [markdown]
# ## Create Folders Train/Val/Test

# %%
DATASET_PATH = "/home/mahirwar/Desktop/Monika/npsad_data/vivek/Datasets/amyb_wsi_v2"
TARGET_PATH = '/home/mahirwar/Desktop/Monika/npsad_data/vivek/Datasets/amyb_wsi_v2/train' # use either train or train_v2
target_folders = ["images", "labels"]
origin_folders = ["image","mask"]
imgs = df1[df1["flag"]=="train"]["file_name"].values
for i in imgs:
   for target_folder,origin_folder in zip(target_folders,origin_folders):
      if i==".DS_Store" :
         continue
      origin = os.path.join(DATASET_PATH,i,origin_folder)
      target = os.path.join(TARGET_PATH,target_folder)
      if not os.path.exists(target):
         os.makedirs(target)
      #print(origin)
      # Fetching the list of all the files
      files = os.listdir(origin)
      #print(files)
      # Fetching all the files to directory
      for file_name in files:
         shutil.copyfile(os.path.join(origin,file_name), os.path.join(target,file_name))
      print("Files are copied successfully")
# Out:
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully

# %%
DATASET_PATH = "/home/mahirwar/Desktop/Monika/npsad_data/vivek/Datasets/amyb_wsi_v2"
TARGET_PATH = '/home/mahirwar/Desktop/Monika/npsad_data/vivek/Datasets/amyb_wsi_v2/val' # use either train or train_v2
target_folders = ["images", "labels"]
origin_folders = ["image","mask"]
imgs = df1[df1["flag"]=="val"]["file_name"].values
for i in imgs:
   for target_folder,origin_folder in zip(target_folders,origin_folders):
      if i==".DS_Store" :
         continue
      origin = os.path.join(DATASET_PATH,i,origin_folder)
      target = os.path.join(TARGET_PATH,target_folder)
      if not os.path.exists(target):
         os.makedirs(target)
      #print(origin)
      # Fetching the list of all the files
      files = os.listdir(origin)
      #print(files)
      # Fetching all the files to directory
      for file_name in files:
         shutil.copyfile(os.path.join(origin,file_name), os.path.join(target,file_name))
      print("Files are copied successfully")
# Out:
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully

# %% [markdown]
# ## Data Augmentation

# %%
all_images = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/",'*.png'))
all_masks = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/",'*.png'))

all_images.sort()
all_masks.sort()

cored_images, cored_masks, diffuse_images, diffuse_masks, cg_images,cg_masks, caa_images, caa_masks  = [],[],[],[],[],[],[],[]
for image, mask in zip(all_images,all_masks):
    found = np.unique(np.array(Image.open(mask)))
    if 50 in found:
        cored_images.append(image)
        cored_masks.append(mask)
    if 100 in found:
        diffuse_images.append(image)
        diffuse_masks.append(mask)
    if 150 in found:
        cg_images.append(image)
        cg_masks.append(mask)
    if 200 in found:
        caa_images.append(image)
        caa_masks.append(mask)

# %%
len(all_images)
# Out:
# 491

# %%
len(cored_images),  len(diffuse_images), len(cg_images), len(caa_images)
# Out:
# (166, 202, 178, 72)

# %%
transforms  = A.Compose([A.VerticalFlip(p=0.5),
                            A.HorizontalFlip(p=0.5),
                            A.Blur(blur_limit=1,p=0.2),
                            A.OpticalDistortion(p=0.25),
                            A.HueSaturationValue(hue_shift_limit=2, sat_shift_limit=3, val_shift_limit=2, p=0.25),
                            A.RandomRotate90(p=0.5),
                            A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.25)
                        ])


def get_randimages_dataug(total_imgs, image_filenames, label_filenames):
    image_filenames.sort()
    label_filenames.sort()
    random_image_file = []
    random_label_file = []
    for i in range(total_imgs):
        random.seed(i)
        random_image_file.append(random.choice(image_filenames))
        random.seed(i)
        random_label_file.append(random.choice(label_filenames))
    return [random_image_file, random_label_file]

def upsample_dataset(dataset_base_dir, random_img_filenames, rand_label_filenames, variations, transforms, dest_img_folder_name, dest_label_folder_name):
    i = 0
    aug_img_files = []
    aug_mask_files = []
    # random.seed(500)

    # Make dir where tha augmented file will reside
    aug_img_dir = os.path.join(dataset_base_dir, dest_img_folder_name)
    if not os.path.exists(aug_img_dir):
            os.makedirs(aug_img_dir)
            print("Augmented Directory '%s' created" %aug_img_dir)
    
    aug_mask_dir = os.path.join(dataset_base_dir, dest_label_folder_name)
    if not os.path.exists(aug_mask_dir):
            os.makedirs(aug_mask_dir)
            print("Augmented Directory '%s' created" %aug_mask_dir)

    print(os.listdir(dataset_base_dir))
    print("\nData Augmentation in Progress ...")
    total_imgs = len(random_img_filenames)
    
    for i in range(total_imgs):
        # load the image
        img = Image.open(random_img_filenames[i]).convert("RGB")
        img = np.array(img)
        mask = Image.open(rand_label_filenames[i]).convert('P')
        mask = np.array(mask)

        for j in range(variations):
                transformed = transforms(image=img, mask=mask)
                transformed_img = transformed["image"]
                transformed_img = Image.fromarray(transformed_img)

                #To rename the file with prefix A_
                filename = os.path.basename(random_img_filenames[i])
                filepath = os.path.dirname(random_img_filenames[i])

                aug_file_name = "A_" + str(i) + "_" + str(j) + "_" + filename
                new_file = os.path.join(dataset_base_dir,dest_img_folder_name,
                                        aug_file_name)
                transformed_img.save(new_file)
                aug_img_files.append(new_file)

                transformed_mask = transformed["mask"]
                transformed_mask = Image.fromarray(transformed_mask)

                #To rename the file with prefix A_
                filename = os.path.basename(rand_label_filenames[i])
                filepath = os.path.dirname(rand_label_filenames[i])
                aug_file_name = "A_" + str(i) + "_" + str(j) + "_" + filename
                new_file = os.path.join(dataset_base_dir, dest_label_folder_name,
                                        aug_file_name)
                transformed_mask.save(new_file)
                aug_mask_files.append(new_file)
    return aug_img_files, aug_mask_files

# %%
"""
aug_value = 100
rand_image_filenames, rand_label_filenames = get_randimages_dataug(aug_value, cg_images, cg_masks)
dataset_base_dir = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train"
aug_img_files, aug_mask_files = upsample_dataset(dataset_base_dir, rand_image_filenames, rand_label_filenames, 1, transforms, "images", "labels")
"""
# Out:
# '\naug_value = 100\nrand_image_filenames, rand_label_filenames = get_randimages_dataug(aug_value, cg_images, cg_masks)\ndataset_base_dir = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train"\naug_img_files, aug_mask_files = upsample_dataset(dataset_base_dir, rand_image_filenames, rand_label_filenames, 1, transforms, "images", "labels")\n'

# %%
aug_value = 50
rand_image_filenames, rand_label_filenames = get_randimages_dataug(aug_value, all_images, all_masks)
dataset_base_dir = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/test_augmentations"
aug_img_files, aug_mask_files = upsample_dataset(dataset_base_dir, rand_image_filenames, rand_label_filenames, 5, transforms, "images", "labels")
# Out:
# ['labels', '.DS_Store', 'images']
#
# Data Augmentation in Progress ...

# %%
all_images = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/",'*.png'))
all_masks = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/",'*.png'))

all_images.sort()
all_masks.sort()

cored_images, cored_masks, diffuse_images, diffuse_masks, cg_images,cg_masks, caa_images, caa_masks  = [],[],[],[],[],[],[],[]
for image, mask in zip(all_images,all_masks):
    found = np.unique(np.array(Image.open(mask)))
    if 50 in found:
        cored_images.append(image)
        cored_masks.append(mask)
    if 100 in found:
        diffuse_images.append(image)
        diffuse_masks.append(mask)
    if 150 in found:
        cg_images.append(image)
        cg_masks.append(mask)
    if 200 in found:
        caa_images.append(image)
        caa_masks.append(mask)

# %%
len(cored_images),  len(diffuse_images), len(cg_images), len(caa_images)
# Out:
# (166, 233, 179, 172)

# %%
all_images = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/",'*.png'))
all_masks = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/",'*.png'))

# %%
all_images.sort()
all_masks.sort()

# %%
len(all_images)
# Out:
# 591

# %%
len(all_masks)
# Out:
# 591

# %%
for image, mask in zip(all_images,all_masks):
    found = np.unique(np.array(Image.open(mask)))
    if len(found)<=1:
        print(image)
        print(mask)
        os.remove(image)
        os.remove(mask)
# Out:
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/XE10-045_1_AmyB_1_71703x_53045y_image.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/XE10-045_1_AmyB_1_71703x_53045y_mask.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/XE12-010_1_AmyB_1_30926x_157422y_image.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/XE12-010_1_AmyB_1_30926x_157422y_mask.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/XE13-007_1_AmyB_1_37037x_114458y_image.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/XE13-007_1_AmyB_1_37037x_114458y_mask.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/XE13-007_1_AmyB_1_88237x_142106y_image.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/XE13-007_1_AmyB_1_88237x_142106y_mask.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/XE18-001_1_AmyB_1_41989x_106305y_image.png
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/XE18-001_1_AmyB_1_41989x_106305y_mask.png

# %%
all_images = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/val/images/",'*.png'))
all_masks = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/val/labels/",'*.png'))

# %%
all_images.sort()
all_masks.sort()
for image, mask in zip(all_images,all_masks):
    found = np.unique(np.array(Image.open(mask)))
    if len(found)<=1:
        print(image)
        os.remove(image)
        os.remove(mask)

# %% [markdown]
# ## Data Augmentation - Normalized

# %%
import glob
all_images = glob.glob(os.path.join("/home/mahirwar/Desktop/Monika/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images",'*.png'))
all_masks = glob.glob(os.path.join("/home/mahirwar/Desktop/Monika/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels",'*.png'))

all_images.sort()
all_masks.sort()

cored_images, cored_masks, diffuse_images, diffuse_masks, cg_images,cg_masks, caa_images, caa_masks  = [],[],[],[],[],[],[],[]
for image, mask in zip(all_images,all_masks):
    found = np.unique(np.array(Image.open(mask)))
    if 50 in found:
        cored_images.append(image)
        cored_masks.append(mask)
    if 100 in found:
        diffuse_images.append(image)
        diffuse_masks.append(mask)
    if 150 in found:
        cg_images.append(image)
        cg_masks.append(mask)
    if 200 in found:
        caa_images.append(image)
        caa_masks.append(mask)

# %%
len(cored_images),  len(diffuse_images), len(cg_images), len(caa_images)
# Out:
# (166, 233, 179, 172)

# %%
transforms  = A.Compose([A.VerticalFlip(p=0.5),
                            A.HorizontalFlip(p=0.5),
                            A.Blur(blur_limit=3),
                            A.OpticalDistortion(),
                            A.HueSaturationValue(),
                            A.RandomRotate90(),
                            A.RandomBrightnessContrast(p=0.2),
                        ])


def get_randimages_dataug(total_imgs, image_filenames, label_filenames):
    image_filenames.sort()
    label_filenames.sort()
    random_image_file = []
    random_label_file = []
    for i in range(total_imgs):
        random.seed(i)
        random_image_file.append(random.choice(image_filenames))
        random.seed(i)
        random_label_file.append(random.choice(label_filenames))
    return [random_image_file, random_label_file]

def upsample_dataset(dataset_base_dir, random_img_filenames, rand_label_filenames, variations, transforms, dest_img_folder_name, dest_label_folder_name):
    i = 0
    aug_img_files = []
    aug_mask_files = []
    # random.seed(500)

    # Make dir where tha augmented file will reside
    aug_img_dir = os.path.join(dataset_base_dir, dest_img_folder_name)
    if not os.path.exists(aug_img_dir):
            os.makedirs(aug_img_dir)
            print("Augmented Directory '%s' created" %aug_img_dir)
    
    aug_mask_dir = os.path.join(dataset_base_dir, dest_label_folder_name)
    if not os.path.exists(aug_mask_dir):
            os.makedirs(aug_mask_dir)
            print("Augmented Directory '%s' created" %aug_mask_dir)

    print(os.listdir(dataset_base_dir))
    print("\nData Augmentation in Progress ...")
    total_imgs = len(random_img_filenames)
    
    for i in range(total_imgs):
        # load the image
        img = Image.open(random_img_filenames[i]).convert("RGB")
        img = np.array(img)
        mask = Image.open(rand_label_filenames[i]).convert('P')
        mask = np.array(mask)

        for j in range(variations):
                transformed = transforms(image=img, mask=mask)
                transformed_img = transformed["image"]
                transformed_img = Image.fromarray(transformed_img)

                #To rename the file with prefix A_
                filename = os.path.basename(random_img_filenames[i])
                filepath = os.path.dirname(random_img_filenames[i])

                aug_file_name = "A_" + str(i) + "_" + str(j) + "_" + filename
                new_file = os.path.join(dataset_base_dir,dest_img_folder_name,
                                        aug_file_name)
                transformed_img.save(new_file)
                aug_img_files.append(new_file)

                transformed_mask = transformed["mask"]
                transformed_mask = Image.fromarray(transformed_mask)

                #To rename the file with prefix A_
                filename = os.path.basename(rand_label_filenames[i])
                filepath = os.path.dirname(rand_label_filenames[i])
                aug_file_name = "A_" + str(i) + "_" + str(j) + "_" + filename
                new_file = os.path.join(dataset_base_dir, dest_label_folder_name,
                                        aug_file_name)
                transformed_mask.save(new_file)
                aug_mask_files.append(new_file)
    return aug_img_files, aug_mask_files

# %%
#aug_value = 100
#rand_image_filenames, rand_label_filenames = get_randimages_dataug(aug_value, cg_images, cg_masks)
dataset_base_dir = "/home/mahirwar/Desktop/Monika/npsad_data/vivek/Datasets/amyb_wsi_v2/train"
aug_img_files, aug_mask_files = upsample_dataset(dataset_base_dir, all_images, all_masks, 5, transforms, "images", "labels")
# Out:
# ['labels', '.DS_Store', 'images']
#
# Data Augmentation in Progress ...

# %%
len(all_images)
# Out:
# 586

# %%
len(all_images)*5
# Out:
# 2930

# %%
len(aug_img_files)
# Out:
# 2930

# %%
len(all_masks)
# Out:
# 586

# %%
all_images = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/images/",'*.png'))
all_masks = glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi_v2/train/labels/",'*.png'))

all_images.sort()
all_masks.sort()

cored_images, cored_masks, diffuse_images, diffuse_masks, cg_images,cg_masks, caa_images, caa_masks  = [],[],[],[],[],[],[],[]
for image, mask in zip(all_images,all_masks):
    found = np.unique(np.array(Image.open(mask)))
    if 50 in found:
        cored_images.append(image)
        cored_masks.append(mask)
    if 100 in found:
        diffuse_images.append(image)
        diffuse_masks.append(mask)
    if 150 in found:
        cg_images.append(image)
        cg_masks.append(mask)
    if 200 in found:
        caa_images.append(image)
        caa_masks.append(mask)

# %%
len(cored_images),  len(diffuse_images), len(cg_images), len(caa_images)
# Out:
# (996, 1398, 1074, 1032)
