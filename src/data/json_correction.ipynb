# %% [markdown]
# ## XE18-003_1_AmyB_1.mrxs

# %%
import json

# %%
#json_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/Amy_plaque_Results/interrater-tool/monika_vivek_interrater_analysis/Ceren_calibrated/XE18-003_1_AmyB_1.mrxs.json"
json_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/Amy_plaque_Results/interrater-tool/monika_vivek_interrater_analysis/Max_calibrated/XE18_003_1_AmyB_1.mrxs.json"

with open(json_path, "r") as jsonFile:
    x = json.load(jsonFile)

# %%
x
# Out:
# [{'type': 'Feature',
#   'id': '225755fc-f961-48aa-b08e-9b799abd4853',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[54149.03, 87443.79],
#      [58267.69, 87443.79],
#      [58267.69, 91562.45],
#      [54149.03, 91562.45],
#      [54149.03, 87443.79]]]},
#   'properties': {'objectType': 'annotation', 'isLocked': True}},
#  {'type': 'Feature',
#   'id': '2f98f545-36eb-4dbe-9fe2-650f33730eaa',
#   'geometry': {'type': 'Point', 'coordinates': [55907.17, 50550.97]},
#   'properties': {'objectType': 'annotation',
#    'name': '49:Diffuse',
#    'color': [255, 153, 102],
#    'classification': {'name': 'Diffuse', 'color': [185, 12, 97]}}},
#  {'type': 'Feature',
#   'id': 'e8ddd0e2-06dd-4fff-aab9-ced60aba9653',
#   'geometry': {'type': 'Point', 'coordinates': [55201.850000000006, 50550.97]},
#   'properties': {'objectType': 'annotation',
#    'name': '52:Diffuse',
#    'color': [255, 153, 102],
#    'classification': {'name': 'Diffuse', 'color': [185, 12, 97]}}},
# ...

# %%
for y in x: 
    if y['geometry']['type'] == "Polygon":
        print(y)
# Out:
# {'type': 'Feature', 'id': '225755fc-f961-48aa-b08e-9b799abd4853', 'geometry': {'type': 'Polygon', 'coordinates': [[[54149.03, 87443.79], [58267.69, 87443.79], [58267.69, 91562.45], [54149.03, 91562.45], [54149.03, 87443.79]]]}, 'properties': {'objectType': 'annotation', 'isLocked': True}}
# {'type': 'Feature', 'id': '0b649ef9-ac6e-4b95-9bd5-020526d04609', 'geometry': {'type': 'Polygon', 'coordinates': [[[45790.48, 87299.58], [49909.14, 87299.58], [49909.14, 91418.24], [45790.48, 91418.24], [45790.48, 87299.58]]]}, 'properties': {'objectType': 'annotation', 'isLocked': True}}

# %%
for y in x: 
    if y['geometry']['type'] == "Point":
        if y['geometry']['coordinates'][0]>=54149.03 and y['geometry']['coordinates'][0]<=58267.69 and y['geometry']['coordinates'][1]<=91562.45 and y['geometry']['coordinates'][1]>=87443.79:
            y['geometry']['coordinates'][0] = y['geometry']['coordinates'][0]+54868-54149.03+100-50
            y['geometry']['coordinates'][1] = y['geometry']['coordinates'][1]-87443.79+46408+50
    
        if y['geometry']['coordinates'][0]>=45790.48 and y['geometry']['coordinates'][0]<=49909.14 and y['geometry']['coordinates'][1]<=91418.24 and y['geometry']['coordinates'][1]>=87299.58:
            y['geometry']['coordinates'][0] = y['geometry']['coordinates'][0]-45790.48+46377+200-50
            y['geometry']['coordinates'][1] = y['geometry']['coordinates'][1]-87299.58+46399

# %%
with open(json_path, 'w') as f:
    json.dump(x, f)

# %% [markdown]
# ## XE19-037_1_AmyB_1.mrxs.json

# %%
json_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/Amy_plaque_Results/interrater-tool/monika_vivek_interrater_analysis/Ceren_calibrated/XE19-037_1_AmyB_1.mrxs.json"
#json_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/Amy_plaque_Results/interrater-tool/monika_vivek_interrater_analysis/Max_calibrated/XE19-037_1_AmyB_1.mrxs.json"

with open(json_path, "r") as jsonFile:
    x = json.load(jsonFile)

# %%
for y in x: 
    if y['geometry']['type'] == "Polygon":
        print(y)
# Out:
# {'type': 'Feature', 'id': '6830fe13-6043-42af-a85a-9a64466a3a3f', 'geometry': {'type': 'Polygon', 'coordinates': [[[55079.73, 79099.26], [59208, 79099.26], [59208, 83308], [55079.73, 83308], [55079.73, 79099.26]]]}, 'properties': {'objectType': 'annotation', 'isLocked': True}}
# {'type': 'Feature', 'id': '58569fc1-0082-4ae0-9461-9dfbb97fea21', 'geometry': {'type': 'Polygon', 'coordinates': [[[50312.26, 150834.62], [54430.92, 150834.62], [54430.92, 154953.28], [50312.26, 154953.28], [50312.26, 150834.62]]]}, 'properties': {'objectType': 'annotation', 'isLocked': True}}

# %%
for y in x: 
    if y['geometry']['type'] == "Point":
        if y['geometry']['coordinates'][0]>=55079.73 and y['geometry']['coordinates'][0]<=59208 and y['geometry']['coordinates'][1]>=79099.26 and y['geometry']['coordinates'][1]<=83308:
            y['geometry']['coordinates'][0] = y['geometry']['coordinates'][0]-55079.73+54807+100
            y['geometry']['coordinates'][1] = y['geometry']['coordinates'][1]-79099.26+92785
    
        if y['geometry']['coordinates'][0]>=50312.26 and y['geometry']['coordinates'][0]<= 54430.92 and y['geometry']['coordinates'][1]>=150834.62 and y['geometry']['coordinates'][1]<=154953.28:
            y['geometry']['coordinates'][0] = y['geometry']['coordinates'][0]-50312.26+50589+100+100
            y['geometry']['coordinates'][1] = y['geometry']['coordinates'][1]-150834.62+164471+100

# %%
with open(json_path, 'w') as f:
    json.dump(x, f)

# %% [markdown]
# ## XE07-049_1_AmyB_1.mrxs.json

# %%
json_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/Amy_plaque_Results/interrater-tool/monika_vivek_interrater_analysis/Ceren/XE07-049_1_AmyB_1.mrxs.json"
#json_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/Amy_plaque_Results/interrater-tool/monika_vivek_interrater_analysis/Max_calibrated/XE07-049_1_AmyB_1.mrxs.json"
with open(json_path, "r") as jsonFile:
    x = json.load(jsonFile)

# %%
for y in x: 
    if y['geometry']['type'] == "Polygon":
        print(y)
# Out:
# {'type': 'Feature', 'id': '7e9a5c28-18f7-4bd9-b653-0b9e7752a012', 'geometry': {'type': 'Polygon', 'coordinates': [[[6814, 66653], [11043, 66653], [11043, 70871], [6814, 70871], [6814, 66653]]]}, 'properties': {'objectType': 'annotation', 'isLocked': True}}
# {'type': 'Feature', 'id': '16e23059-3c02-49fc-aff9-ff50fcd3d317', 'geometry': {'type': 'Polygon', 'coordinates': [[[65909, 116529], [70122, 116529], [70122, 120758], [65909, 120758], [65909, 116529]]]}, 'properties': {'objectType': 'annotation', 'isLocked': True}}
# {'type': 'Feature', 'id': '7e9a5c28-18f7-4bd9-b653-0b9e7752a012', 'geometry': {'type': 'Polygon', 'coordinates': [[[8424, 67429], [12653, 67429], [12653, 71647], [8424, 71647], [8424, 67429]]]}, 'properties': {'objectType': 'annotation', 'isLocked': True}}
# ...

# %%
for y in x: 
    if y['geometry']['type'] == "Point":
        if y['geometry']['coordinates'][0]>=6814 and y['geometry']['coordinates'][0]<=11043 and y['geometry']['coordinates'][1]<=70871 and y['geometry']['coordinates'][1]>=66653 :
            y['geometry']['coordinates'][0] = y['geometry']['coordinates'][0]+8424-6814
            y['geometry']['coordinates'][1] = y['geometry']['coordinates'][1]+67429-66653
    
        if y['geometry']['coordinates'][0]>=65909 and  y['geometry']['coordinates'][0]<=70122 and y['geometry']['coordinates'][1]<=120758 and y['geometry']['coordinates'][1]>=116529:
            y['geometry']['coordinates'][0] = y['geometry']['coordinates'][0]+67425-65909
            y['geometry']['coordinates'][1] = y['geometry']['coordinates'][1]+117984-116529

# %%
json_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/Amy_plaque_Results/interrater-tool/monika_vivek_interrater_analysis/Ceren_calibrated/XE07-049_1_AmyB_1.mrxs.json"

with open(json_path, 'w') as f:
    json.dump(x, f)
