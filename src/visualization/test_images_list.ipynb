# %%
import pandas as pd
import glob
import os
import shutil
import numpy as np
import random

# %% [markdown]
# ## Move missing items in another folder

# %%
input_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test-patients/images/"

# %%
missing_images = pd.read_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/missing_content_amyb-def-mfg.csv")

# %%
missing_images_list = list(missing_images["id"].values)

# %%
image_paths = glob.glob(os.path.join(input_path,"*"))

# %%
len(image_paths)
# Out:
# 91

# %%
for img in image_paths:
    if img.split("/")[-1] in missing_images_list:
        src_path = img
        dst_path = os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test-missing/",img.split("/")[-1])
        #print(dst_path)
        shutil.move(src_path, dst_path)

# %% [markdown]
# ## Select files pending run

# %%
input_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test-patients/images/"

# %%
image_paths = glob.glob(os.path.join(input_path,"*"))

# %%
len(image_paths)
# Out:
# 69

# %%
merged_csv = pd.read_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/csv_merged_data/final_quantify_internal_dataset.csv")

# %%
run_completed_list = list(merged_csv["image_name"].values)

# %%
len(run_completed_list)
# Out:
# 32

# %%
df = pd.DataFrame({"wsi_name":image_paths})

# %%
df
# Out:
#                                              wsi_name
# 0   /gladstone/finkbeiner/steve/work/data/npsad_da...
# 1   /gladstone/finkbeiner/steve/work/data/npsad_da...
# 2   /gladstone/finkbeiner/steve/work/data/npsad_da...
# 3   /gladstone/finkbeiner/steve/work/data/npsad_da...
# 4   /gladstone/finkbeiner/steve/work/data/npsad_da...
# ..                                                ...
# 66  /gladstone/finkbeiner/steve/work/data/npsad_da...
# 67  /gladstone/finkbeiner/steve/work/data/npsad_da...
# 68  /gladstone/finkbeiner/steve/work/data/npsad_da...
# 69  /gladstone/finkbeiner/steve/work/data/npsad_da...
# 70  /gladstone/finkbeiner/steve/work/data/npsad_da...
#
# [71 rows x 1 columns]

# %%
df["run_completed"] = df["wsi_name"].apply(lambda l:1 if l.split("/")[-1] in run_completed_list else 0  )

# %%
len(df[df["run_completed"]==0])
# Out:
# 41

# %%
df = df.sort_values(by="run_completed")

# %%
df["sort_index"] = np.arange(0,71)

# %%
df.drop(["flag1"],axis=1,inplace=True)

# %%
df["flag"] = np.where(df["sort_index"]<=20,"M", np.where(df["sort_index"]<=40, "V", None))

# %%
df["flag"].value_counts()
# Out:
# M    21
# V    20
# Name: flag, dtype: int64

# %%
df.to_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test_files_to_run.csv")

# %% [markdown]
# ## File count Check

# %%
full_df = pd.read_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/AmyB/Total_Amyb.csv")

# %%
full_df
# Out:
#      Unnamed: 0  index                FileName     XENum  \
# 0             0      0  XE07-002_1_AmyB_1.mrxs  XE07-002
# 1             1      1  XE07-027_1_AmyB_1.mrxs  XE07-027
# 2             2      2  XE07-033_1_AmyB_1.mrxs  XE07-033
# 3             3      3  XE07-034_1_AmyB_1.mrxs  XE07-034
# 4             4      4  XE07-036_1_AmyB_1.mrxs  XE07-036
# ..          ...    ...                     ...       ...
# 206         206     49  XE12-031_1_AmyB_1.mrxs  XE12-031
# 207         207     50  XE12-036_1_AmyB_1.mrxs  XE12-036
# 208         208     53  XE13-003_1_AmyB_1.mrxs  XE13-003
# 209         209     59  XE13-028_1_AmyB_1.mrxs  XE13-028
# 210         210     62  XE14-033_1_AmyB_1.mrxs  XE14-033
#
#               BrainRegion         Stain  SeqNum    SentDate    BB  SubNum  \
# 0    Middle Frontal Gyrus  Amyloid Beta       1  12/21/2020  1383    4458
# 1    Middle Frontal Gyrus  Amyloid Beta       1  12/21/2020  1406   26772
# ...

# %%
missing_df = pd.read_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/AmyB/missing_content_amyb-def-mfg.csv")

# %%
missing_df["FileName"].values
# Out:
# array(['XE07-057_1_AmyB_1.mrxs', 'XE08-018_1_AmyB_1.mrxs',
#        'XE10-006_1_AmyB_1.mrxs', 'XE10-009_1_AmyB_1.mrxs',
#        'XE10-018_1_AmyB_1.mrxs', 'XE10-019_1_AmyB_1.mrxs',
#        'XE10-020_1_AmyB_1.mrxs', 'XE10-021_1_AmyB_1.mrxs',
#        'XE10-026_1_AmyB_1.mrxs', 'XE11-008_1_AmyB_1.mrxs',
#        'XE11-018_1_AmyB_1.mrxs', 'XE11-025_1_AmyB_1.mrxs',
#        'XE11-029_1_AmyB_1.mrxs', 'XE12-009_1_AmyB_1.mrxs',
#        'XE12-023_1_AmyB_1.mrxs', 'XE12-031_1_AmyB_1.mrxs',
#        'XE12-036_1_AmyB_1.mrxs', 'XE13-003_1_AmyB_1.mrxs',
#        'XE13-028_1_AmyB_1.mrxs', 'XE14-033_1_AmyB_1.mrxs'], dtype=object)

# %%
new_amy = full_df[~full_df['FileName'].isin(missing_df['FileName'])]

# %%
len(new_amy)
# Out:
# 172

# %%
amy_def = pd.read_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/AmyB/amyb_addef_mfg.csv")

# %%
len(amy_def)
# Out:
# 70

# %%
new_amy1 = new_amy[~new_amy['FileName'].isin(amy_def['FileName'])]

# %%
len(new_amy1)
# Out:
# 121

# %%
amy_def[~amy_def["FileName"].isin(new_amy["FileName"])].to_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/AmyB/extra_files.csv")

# %%
extra_files = amy_def[~amy_def["FileName"].isin(new_amy["FileName"])]

# %%
full_df= full_df.append(extra_files)
# Out:
# /tmp/ipykernel_76864/2448191872.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   full_df= full_df.append(extra_files)

# %%
full_df=full_df.reset_index()

# %%
full_df.to_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/AmyB/Total_Amyb.csv")

# %%
len(full_df)
# Out:
# 211

# %%
full_df
# Out:
#      index                FileName     XENum           BrainRegion  \
# 0        0  XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus
# 1        1  XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus
# 2        2  XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus
# 3        3  XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus
# 4        4  XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus
# ..     ...                     ...       ...                   ...
# 206     49  XE12-031_1_AmyB_1.mrxs  XE12-031  Middle Frontal Gyrus
# 207     50  XE12-036_1_AmyB_1.mrxs  XE12-036  Middle Frontal Gyrus
# 208     53  XE13-003_1_AmyB_1.mrxs  XE13-003  Middle Frontal Gyrus
# 209     59  XE13-028_1_AmyB_1.mrxs  XE13-028  Middle Frontal Gyrus
# 210     62  XE14-033_1_AmyB_1.mrxs  XE14-033  Middle Frontal Gyrus
#
#             Stain  SeqNum    SentDate    BB  SubNum   SubID Brain_bank   Age  \
# 0    Amyloid Beta       1  12/21/2020  1383    4458     NaN        NaN   NaN
# ...

# %%
new_amy1 = new_amy[~new_amy['FileName'].isin(amy_def['FileName'])]

# %%
192+19
# Out:
# 211

# %%
211-20-71
# Out:
# 120

# %%
amy_def
# Out:
#                   FileName     XENum           BrainRegion         Stain  \
# 0   XE07-047_1_AmyB_1.mrxs  XE07-047  Middle Frontal Gyrus  Amyloid Beta
# 1   XE07-048_1_AmyB_1.mrxs  XE07-048  Middle Frontal Gyrus  Amyloid Beta
# 2   XE07-049_1_AmyB_1.mrxs  XE07-049  Middle Frontal Gyrus  Amyloid Beta
# 3   XE07-056_1_AmyB_1.mrxs  XE07-056  Middle Frontal Gyrus  Amyloid Beta
# 4   XE07-060_1_AmyB_1.mrxs  XE07-060  Middle Frontal Gyrus  Amyloid Beta
# ..                     ...       ...                   ...           ...
# 65  XE14-051_1_AmyB_1.mrxs  XE14-051  Middle Frontal Gyrus  Amyloid Beta
# 66  XE15-012_1_AmyB_1.mrxs  XE15-012  Middle Frontal Gyrus  Amyloid Beta
# 67  XE15-039_1_AmyB_1.mrxs  XE15-039  Middle Frontal Gyrus  Amyloid Beta
# 68  XE15-051_1_AmyB_1.mrxs  XE15-051  Middle Frontal Gyrus  Amyloid Beta
# 69  XE15-022_1_AmyB_1.mrxs  XE15-022  Middle Frontal Gyrus  Amyloid Beta
#
#     SeqNum    BB  SubNum   SubID Brain_bank  Age     Sex Ethnicity    key_1  \
# ...

# %%
l =["XE17-013_1_AmyB_1.mrxs", "XE18-001_7_AmyB_1.mrxs", "XE17-029_1_AmyB_1.mrxs", "XE11-039_1_AmyB_1.mrxs", "XE18-003_1_AmyB_1.mrxs", "XE15-039_1_AmyB_1.mrxs", "XE17-010_1_AmyB_1.mrxs", "XE19-037_1_AmyB_1.mrxs", "XE08-010_1_AmyB_1.mrxs", "XE18-040_1_AmyB_1.mrxs", "XE17-048_1_AmyB_1.mrxs", "XE10-045_1_AmyB_1.mrxs", "XE12-015_1_AmyB_1.mrxs", "XE19-028_5_AmyB_1.mrxs", "XE18-066_1_AmyB_1.mrxs", "XE16-021_1_AmyB_1.mrxs", "XE17-059_1_AmyB_1.mrxs", "XE15-007_1_AmyB_1.mrxs", "XE17-022_1_AmyB_1.mrxs", "XE17-004_1_AmyB_1.mrxs", "XE07-060_1_AmyB_1.mrxs", "XE14-037_1_AmyB_1.mrxs", "XE14-051_1_AmyB_1.mrxs", "XE18-045_1_AmyB_1.mrxs", "XE17-039_6_AmyB_1.mrxs", "XE07-056_1_AmyB_1.mrxs", "XE08-047_1_AmyB_1.mrxs", "XE17-014_1_AmyB_1.mrxs", "XE17-039_7_AmyB_1.mrxs", "XE16-057_1_AmyB_1.mrxs", "XE12-012_1_AmyB_1.mrxs", "XE08-016_1_AmyB_1.mrxs", "XE19-028_1_AmyB_1.mrxs", "XE17-022_7_AmyB_1.mrxs", "XE17-065_1_AmyB_1.mrxs", "XE16-033_1_AmyB_1.mrxs", "XE18-003_6_AmyB_1.mrxs", "XE09-028_1_AmyB_1.mrxs", "XE16-002_7_AmyB_1.mrxs", "XE12-007_1_AmyB_1.mrxs", "XE17-039_1_AmyB_1.mrxs", "XE16-055_1_AmyB_1.mrxs", "XE16-057_7_AmyB_1.mrxs", "XE11-027_1_AmyB_1.mrxs", "XE13-029_1_AmyB_1.mrxs", "XE17-059_7_AmyB_1.mrxs", "XE10-030_1_AmyB_1.mrxs", "XE07-067_1_AmyB_1.mrxs", "XE13-017_1_AmyB_1.mrxs", "XE12-037_1_AmyB_1.mrxs", "XE08-015_1_AmyB_1.mrxs", "XE10-033_1_AmyB_1.mrxs", "XE16-014_1_AmyB_1.mrxs", "XE13-018_1_AmyB_1.mrxs", "XE16-053_6_AmyB_1.mrxs", "XE09-056_1_AmyB_1.mrxs", "XE12-010_1_AmyB_1.mrxs", "XE07-049_1_AmyB_1.mrxs", "XE14-047_1_AmyB_1.mrxs", "XE15-012_1_AmyB_1.mrxs", "XE17-029_7_AmyB_1.mrxs", "XE17-013_7_AmyB_1.mrxs", "XE16-055_7_AmyB_1.mrxs", "XE16-053_7_AmyB_1.mrxs", "XE07-048_1_AmyB_1.mrxs", "XE15-012_7_AmyB_1.mrxs", "XE12-016_1_AmyB_1.mrxs", "XE15-051_1_AmyB_1.mrxs", "XE18-004_7_AmyB_1.mrxs", "XE10-046_1_AmyB_1.mrxs", "XE13-005_1_AmyB_1.mrxs", "XE09-063_1_AmyB_1.mrxs", "XE18-001_1_AmyB_1.mrxs", "XE17-048_7_AmyB_1.mrxs", "XE17-065_6_AmyB_1.mrxs", "XE12-042_1_AmyB_1.mrxs", "XE13-003_1_AmyB_1.mrxs", "XE16-021_7_AmyB_1.mrxs", "XE17-014_6_AmyB_1.mrxs", "XE13-020_1_AmyB_1.mrxs", "XE16-033_7_AmyB_1.mrxs", "XE13-007_1_AmyB_1.mrxs", "XE09-006_1_AmyB_1.mrxs", "XE10-005_1_AmyB_1.mrxs", "XE15-007_7_AmyB_1.mrxs", "XE10-053_1_AmyB_1.mrxs", "XE15-022_1_AmyB_1.mrxs", "XE09-049_1_AmyB_1.mrxs", "XE18-004_1_AmyB_1.mrxs", "XE14-004_6_AmyB_1.mrxs", "XE16-027_1_AmyB_1.mrxs", "XE18-004_6_AmyB_1.mrxs", "XE10-021_1_AmyB_1.mrxs", "XE18-043_1_AmyB_1.mrxs", "XE07-047_1_AmyB_1.mrxs", "XE09-013_1_AmyB_1.mrxs", "XE09-035_1_AmyB_1.mrxs", "XE12-009_1_AmyB_1.mrxs", "XE16-027_7_AmyB_1.mrxs", "XE08-017_1_AmyB_1.mrxs", "XE10-020_1_AmyB_1.mrxs", "XE16-023_7_AmyB_1.mrxs", "XE15-022_7_AmyB_1.mrxs", "XE87-008_6_AmyB_1.mrxs", "XE10-042_1_AmyB_1.mrxs", "XE12-023_1_AmyB_1.mrxs", "XE10-006_1_AmyB_1.mrxs", "XE13-028_1_AmyB_1.mrxs", "XE08-033_1_AmyB_1.mrxs", "XE09-041_1_AmyB_1.mrxs", "XE12-036_1_AmyB_1.mrxs", "XE16-053_1_AmyB_1.mrxs", "XE11-028_6_AmyB_1.mrxs", "XE11-025_1_AmyB_1.mrxs", "XE11-008_1_AmyB_1.mrxs", "XE10-006_7_AmyB_1.mrxs", "XE10-026_1_AmyB_1.mrxs", "XE14-033_1_AmyB_1.mrxs", "XE16-002_1_AmyB_1.mrxs", "XE17-030_1_AmyB_1.mrxs", "XE12-013_1_AmyB_1.mrxs", "XE08-018_1_AmyB_1.mrxs", "XE14-004_1_AmyB_1.mrxs", "XE07-064_1_AmyB_1.mrxs", "XE10-019_1_AmyB_1.mrxs", "XE07-057_1_AmyB_1.mrxs", "XE11-029_1_AmyB_1.mrxs", "XE12-031_1_AmyB_1.mrxs", "XE10-009_1_AmyB_1.mrxs", "XE11-018_1_AmyB_1.mrxs", "XE10-018_1_AmyB_1.mrxs", "XE12-011_1_AmyB_1.mrxs", "XE16-023_1_AmyB_1.mrxs"]

# %%
wynton_files = pd.DataFrame({"FileName":l})

# %%
wynton_files["FileName"].values
# Out:
# array(['XE17-013_1_AmyB_1.mrxs', 'XE18-001_7_AmyB_1.mrxs',
#        'XE17-029_1_AmyB_1.mrxs', 'XE11-039_1_AmyB_1.mrxs',
#        'XE18-003_1_AmyB_1.mrxs', 'XE15-039_1_AmyB_1.mrxs',
#        'XE17-010_1_AmyB_1.mrxs', 'XE19-037_1_AmyB_1.mrxs',
#        'XE08-010_1_AmyB_1.mrxs', 'XE18-040_1_AmyB_1.mrxs',
#        'XE17-048_1_AmyB_1.mrxs', 'XE10-045_1_AmyB_1.mrxs',
#        'XE12-015_1_AmyB_1.mrxs', 'XE19-028_5_AmyB_1.mrxs',
#        'XE18-066_1_AmyB_1.mrxs', 'XE16-021_1_AmyB_1.mrxs',
#        'XE17-059_1_AmyB_1.mrxs', 'XE15-007_1_AmyB_1.mrxs',
#        'XE17-022_1_AmyB_1.mrxs', 'XE17-004_1_AmyB_1.mrxs',
#        'XE07-060_1_AmyB_1.mrxs', 'XE14-037_1_AmyB_1.mrxs',
#        'XE14-051_1_AmyB_1.mrxs', 'XE18-045_1_AmyB_1.mrxs',
#        'XE17-039_6_AmyB_1.mrxs', 'XE07-056_1_AmyB_1.mrxs',
#        'XE08-047_1_AmyB_1.mrxs', 'XE17-014_1_AmyB_1.mrxs',
#        'XE17-039_7_AmyB_1.mrxs', 'XE16-057_1_AmyB_1.mrxs',
#        'XE12-012_1_AmyB_1.mrxs', 'XE08-016_1_AmyB_1.mrxs',
# ...

# %%
new_amy = full_df[~full_df['FileName'].isin(missing_df['FileName'])]

# %%
len(new_amy)
# Out:
# 172

# %%
new_amy1 = new_amy[~new_amy['FileName'].isin(amy_def['FileName'])]

# %%
len(new_amy1)
# Out:
# 121

# %%
new_amy1
# Out:
#      index                FileName     XENum           BrainRegion  \
# 0        0  XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus
# 1        1  XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus
# 2        2  XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus
# 3        3  XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus
# 4        4  XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus
# ..     ...                     ...       ...                   ...
# 186    186  XE15-001_1_AmyB_1.mrxs  XE15-001  Middle Frontal Gyrus
# 187    187  XE15-018_1_AmyB_1.mrxs  XE15-018  Middle Frontal Gyrus
# 188    188  XE15-019_1_AmyB_1.mrxs  XE15-019  Middle Frontal Gyrus
# 190    190  XE15-024_1_AmyB_1.mrxs  XE15-024  Middle Frontal Gyrus
# 191    191  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus
#
#             Stain  SeqNum    SentDate    BB  SubNum SubID Brain_bank  Age  \
# 0    Amyloid Beta       1  12/21/2020  1383    4458   NaN        NaN  NaN
# ...

# %%
new_amy2 = new_amy1[new_amy1['FileName'].isin(wynton_files['FileName'])]

# %%
new_amy2
# Out:
#      index                FileName     XENum           BrainRegion  \
# 94      94  XE10-045_1_AmyB_1.mrxs  XE10-045  Middle Frontal Gyrus
# 120    120  XE12-011_1_AmyB_1.mrxs  XE12-011  Middle Frontal Gyrus
# 166    166  XE15-007_1_AmyB_1.mrxs  XE15-007  Middle Frontal Gyrus
#
#             Stain  SeqNum    SentDate    BB  SubNum SubID Brain_bank  Age  \
# 94   Amyloid Beta       1  12/21/2020  1598   48979   NaN        NaN  NaN
# 120  Amyloid Beta       1  12/21/2020  1655   46382   NaN        NaN  NaN
# 166  Amyloid Beta       1  12/21/2020  1783   58832   NaN        NaN  NaN
#
#      Sex Ethnicity key_1 key_2 key_3
# 94   NaN       NaN   NaN   NaN   NaN
# 120  NaN       NaN   NaN   NaN   NaN
# 166  NaN       NaN   NaN   NaN   NaN

# %%
full_df[~full_df['FileName'].isin(wynton_files['FileName'])]
# Out:
#      index                FileName     XENum           BrainRegion  \
# 0        0  XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus
# 1        1  XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus
# 2        2  XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus
# 3        3  XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus
# 4        4  XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus
# ..     ...                     ...       ...                   ...
# 186    186  XE15-001_1_AmyB_1.mrxs  XE15-001  Middle Frontal Gyrus
# 187    187  XE15-018_1_AmyB_1.mrxs  XE15-018  Middle Frontal Gyrus
# 188    188  XE15-019_1_AmyB_1.mrxs  XE15-019  Middle Frontal Gyrus
# 190    190  XE15-024_1_AmyB_1.mrxs  XE15-024  Middle Frontal Gyrus
# 191    191  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus
#
#             Stain  SeqNum    SentDate    BB  SubNum SubID Brain_bank  Age  \
# 0    Amyloid Beta       1  12/21/2020  1383    4458   NaN        NaN  NaN
# ...

# %%
len(full_df)
# Out:
# 211

# %% [markdown]
# ## Get Clinical Metadata

# %%
img_data = pd.read_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/NPSAD_image_metadata (2).csv")

# %%
clinical_data = pd.read_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/clinical_metadata (5).csv")

# %%
clinical_data1 = clinical_data[["SubID","Brain_bank","Dx","CERAD","CDRScore","Plq_Mn","Plq_Mn_MFG", "AD","MCI","Dementia","PD"]]
clinical_data1 = clinical_data1[clinical_data1["Brain_bank"]=="MSSM"]

# %%
len(clinical_data1)
# Out:
# 1248

# %%
clinical_data1.head(2)
# Out:
#       SubID Brain_bank                                                 Dx  \
# 0  M00_1061       MSSM  Harry's plaintext: CVD+BPD | CERAD_1: Vascular...
# 1  M00_1062       MSSM  Harry's plaintext: CVD | CERAD_1: Vascular dis...
#
#    CERAD  CDRScore  Plq_Mn  Plq_Mn_MFG   AD  MCI  Dementia  PD
# 0    NaN       0.5     0.0         NaN  0.0  1.0       0.0   0
# 1    NaN       0.0     0.0         NaN  0.0  0.0       0.0   0

# %%
len(clinical_data1)
# Out:
# 1248

# %%
clinical_data.columns
# Out:
# Index(['SubID', 'Brain_bank', 'Age', 'Sex', 'Sex_chr_aneuploidy', 'Ethnicity',
#        'Dx', 'pH', 'PMI', 'Death_Time',
#        ...
#        'LewyNucleusValue', 'LewyLocusValue', 'LewyDorsalVValue', 'CDR_Memory',
#        'CDR_Orientation', 'CDR_Judgement', 'CDR_Community', 'CDR_HomeHobbies',
#        'CDR_PersonalCare', 'CDR_SumBoxes'],
#       dtype='object', length=237)

# %%
img_data["Stain"].unique()
# Out:
# array(['H&E', 'Modified Beilschowski', 'Synuclein', 'Amyloid Beta', 'Tau'],
#       dtype=object)

# %%
img_data1 = img_data[(img_data["BrainRegion"]=='Middle Frontal Gyrus') & (img_data["Stain"]=='Amyloid Beta')]

# %%
img_data1
# Out:
#                     FileName     XENum           BrainRegion         Stain  \
# 535   XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus  Amyloid Beta
# 576   XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus  Amyloid Beta
# 587   XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus  Amyloid Beta
# 591   XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus  Amyloid Beta
# 594   XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus  Amyloid Beta
# ...                      ...       ...                   ...           ...
# 3577  XE15-018_1_AmyB_1.mrxs  XE15-018  Middle Frontal Gyrus  Amyloid Beta
# 3585  XE15-019_1_AmyB_1.mrxs  XE15-019  Middle Frontal Gyrus  Amyloid Beta
# 3598  XE15-022_1_AmyB_1.mrxs  XE15-022  Middle Frontal Gyrus  Amyloid Beta
# 3610  XE15-024_1_AmyB_1.mrxs  XE15-024  Middle Frontal Gyrus  Amyloid Beta
# 3656  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus  Amyloid Beta
#
#       SeqNum    SentDate      BB  SubNum
# ...

# %%
img_data1["SubNum_with_M"]=img_data1["SubNum"].apply(lambda l:"M"+str(l))
# Out:
# /tmp/ipykernel_76864/506788767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   img_data1["SubNum_with_M"]=img_data1["SubNum"].apply(lambda l:"M"+str(l))

# %%
img_clinical = pd.merge(img_data1,clinical_data1, left_on="SubNum_with_M", right_on="SubID", how="left")

# %%
img_clinical["SubID"].isna().sum()
# Out:
# 1

# %%
191+20
# Out:
# 211

# %%
XE07-057

# %%
img_clinical_tmp = img_clinical[~img_clinical['FileName'].isin(wynton_files['FileName'])]

# %%
img_clinical_tmp
# Out:
#                    FileName     XENum           BrainRegion         Stain  \
# 0    XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus  Amyloid Beta
# 1    XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus  Amyloid Beta
# 2    XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus  Amyloid Beta
# 3    XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus  Amyloid Beta
# 4    XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus  Amyloid Beta
# ..                      ...       ...                   ...           ...
# 186  XE15-001_1_AmyB_1.mrxs  XE15-001  Middle Frontal Gyrus  Amyloid Beta
# 187  XE15-018_1_AmyB_1.mrxs  XE15-018  Middle Frontal Gyrus  Amyloid Beta
# 188  XE15-019_1_AmyB_1.mrxs  XE15-019  Middle Frontal Gyrus  Amyloid Beta
# 190  XE15-024_1_AmyB_1.mrxs  XE15-024  Middle Frontal Gyrus  Amyloid Beta
# 191  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus  Amyloid Beta
#
#      SeqNum    SentDate      BB  SubNum SubNum_with_M    SubID Brain_bank  \
# ...

# %%
192-119
# Out:
# 73

# %%
len(wynton_files)
# Out:
# 133

# %% [markdown]
# ## Get Clinical Metadata - Check all regions

# %%
img_data2 = img_data[img_data["Stain"]=='Amyloid Beta']

# %%
img_data2
# Out:
#                     FileName     XENum           BrainRegion         Stain  \
# 535   XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus  Amyloid Beta
# 576   XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus  Amyloid Beta
# 587   XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus  Amyloid Beta
# 591   XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus  Amyloid Beta
# 594   XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus  Amyloid Beta
# ...                      ...       ...                   ...           ...
# 3653  XE19-005_7_AmyB_1.mrxs  XE19-005    Caudal Hippocampus  Amyloid Beta
# 3656  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus  Amyloid Beta
# 3658  XE19-057_5_AmyB_1.mrxs  XE19-057    Caudal Hippocampus  Amyloid Beta
# 3662  XE19-060_5_AmyB_1.mrxs  XE19-060    Caudal Hippocampus  Amyloid Beta
# 3677  XE87-008_6_AmyB_1.mrxs  XE87-008   Rostral Hippocampus  Amyloid Beta
#
#       SeqNum    SentDate      BB  SubNum SubNum_with_M
# ...

# %%
img_data2["SubNum_with_M"]=img_data2["SubNum"].apply(lambda l:"M"+str(l))
#img_data["SubNum_with_M"]=img_data["SubNum"].apply(lambda l:"M"+str(l))
# Out:
# /tmp/ipykernel_76864/3696694498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   img_data2["SubNum_with_M"]=img_data2["SubNum"].apply(lambda l:"M"+str(l))

# %%
img_data2
# Out:
#                     FileName     XENum           BrainRegion         Stain  \
# 535   XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus  Amyloid Beta
# 576   XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus  Amyloid Beta
# 587   XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus  Amyloid Beta
# 591   XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus  Amyloid Beta
# 594   XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus  Amyloid Beta
# ...                      ...       ...                   ...           ...
# 3653  XE19-005_7_AmyB_1.mrxs  XE19-005    Caudal Hippocampus  Amyloid Beta
# 3656  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus  Amyloid Beta
# 3658  XE19-057_5_AmyB_1.mrxs  XE19-057    Caudal Hippocampus  Amyloid Beta
# 3662  XE19-060_5_AmyB_1.mrxs  XE19-060    Caudal Hippocampus  Amyloid Beta
# 3677  XE87-008_6_AmyB_1.mrxs  XE87-008   Rostral Hippocampus  Amyloid Beta
#
#       SeqNum    SentDate      BB  SubNum SubNum_with_M
# ...

# %%
#img_clinical2 = pd.merge(img_data2,clinical_data1, left_on="SubNum_with_M", right_on="SubID", how="left")
img_clinical2 = pd.merge(img_data2,clinical_data1, left_on="SubNum_with_M", right_on="SubID", how="left")

# %%
img_clinical2
# Out:
#                    FileName     XENum           BrainRegion         Stain  \
# 0    XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus  Amyloid Beta
# 1    XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus  Amyloid Beta
# 2    XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus  Amyloid Beta
# 3    XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus  Amyloid Beta
# 4    XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus  Amyloid Beta
# ..                      ...       ...                   ...           ...
# 212  XE19-005_7_AmyB_1.mrxs  XE19-005    Caudal Hippocampus  Amyloid Beta
# 213  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus  Amyloid Beta
# 214  XE19-057_5_AmyB_1.mrxs  XE19-057    Caudal Hippocampus  Amyloid Beta
# 215  XE19-060_5_AmyB_1.mrxs  XE19-060    Caudal Hippocampus  Amyloid Beta
# 216  XE87-008_6_AmyB_1.mrxs  XE87-008   Rostral Hippocampus  Amyloid Beta
#
#      SeqNum    SentDate      BB  SubNum SubNum_with_M    SubID Brain_bank  \
# ...

# %%
wynton_files['FileName']
# Out:
# 0      XE17-013_1_AmyB_1.mrxs
# 1      XE18-001_7_AmyB_1.mrxs
# 2      XE17-029_1_AmyB_1.mrxs
# 3      XE11-039_1_AmyB_1.mrxs
# 4      XE18-003_1_AmyB_1.mrxs
#                 ...
# 128    XE10-009_1_AmyB_1.mrxs
# 129    XE11-018_1_AmyB_1.mrxs
# 130    XE10-018_1_AmyB_1.mrxs
# 131    XE12-011_1_AmyB_1.mrxs
# 132    XE16-023_1_AmyB_1.mrxs
# Name: FileName, Length: 133, dtype: object

# %%
img_clinical_tmp2 = img_clinical2[~img_clinical2['FileName'].isin(wynton_files['FileName'])]

# %%
wynton_files[~wynton_files['FileName'].isin(img_clinical2['FileName'])]
# Out:
#                    FileName
# 0    XE17-013_1_AmyB_1.mrxs
# 1    XE18-001_7_AmyB_1.mrxs
# 2    XE17-029_1_AmyB_1.mrxs
# 4    XE18-003_1_AmyB_1.mrxs
# 6    XE17-010_1_AmyB_1.mrxs
# 7    XE19-037_1_AmyB_1.mrxs
# 9    XE18-040_1_AmyB_1.mrxs
# 10   XE17-048_1_AmyB_1.mrxs
# 13   XE19-028_5_AmyB_1.mrxs
# 14   XE18-066_1_AmyB_1.mrxs
# 15   XE16-021_1_AmyB_1.mrxs
# 16   XE17-059_1_AmyB_1.mrxs
# 18   XE17-022_1_AmyB_1.mrxs
# 19   XE17-004_1_AmyB_1.mrxs
# 23   XE18-045_1_AmyB_1.mrxs
# 24   XE17-039_6_AmyB_1.mrxs
# 27   XE17-014_1_AmyB_1.mrxs
# 28   XE17-039_7_AmyB_1.mrxs
# 29   XE16-057_1_AmyB_1.mrxs
# 32   XE19-028_1_AmyB_1.mrxs
# 33   XE17-022_7_AmyB_1.mrxs
# 34   XE17-065_1_AmyB_1.mrxs
# 35   XE16-033_1_AmyB_1.mrxs
# 36   XE18-003_6_AmyB_1.mrxs
# 38   XE16-002_7_AmyB_1.mrxs
# 40   XE17-039_1_AmyB_1.mrxs
# 41   XE16-055_1_AmyB_1.mrxs
# 42   XE16-057_7_AmyB_1.mrxs
# 45   XE17-059_7_AmyB_1.mrxs
# 52   XE16-014_1_AmyB_1.mrxs
# 54   XE16-053_6_AmyB_1.mrxs
# 60   XE17-029_7_AmyB_1.mrxs
# ...

# %%
img_clinical_tmp2
# Out:
#                    FileName     XENum           BrainRegion         Stain  \
# 0    XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus  Amyloid Beta
# 1    XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus  Amyloid Beta
# 2    XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus  Amyloid Beta
# 3    XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus  Amyloid Beta
# 4    XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus  Amyloid Beta
# ..                      ...       ...                   ...           ...
# 211  XE15-024_7_AmyB_1.mrxs  XE15-024    Caudal Hippocampus  Amyloid Beta
# 212  XE19-005_7_AmyB_1.mrxs  XE19-005    Caudal Hippocampus  Amyloid Beta
# 213  XE19-054_1_AmyB_1.mrxs  XE19-054  Middle Frontal Gyrus  Amyloid Beta
# 214  XE19-057_5_AmyB_1.mrxs  XE19-057    Caudal Hippocampus  Amyloid Beta
# 215  XE19-060_5_AmyB_1.mrxs  XE19-060    Caudal Hippocampus  Amyloid Beta
#
#      SeqNum    SentDate      BB  SubNum SubNum_with_M    SubID Brain_bank  \
# ...

# %%
clinical_data1
# Out:
#              SubID Brain_bank  \
# 0         M00_1061       MSSM
# 1         M00_1062       MSSM
# 2     M00_BM444996       MSSM
# 3           M10001       MSSM
# 4           M10031       MSSM
# ...            ...        ...
# 1243        M99645       MSSM
# 1244        M99877       MSSM
# 1245        M99891       MSSM
# 1246        M99907       MSSM
# 1247        M99926       MSSM
#
#                                                      Dx  CERAD  CDRScore  \
# 0     Harry's plaintext: CVD+BPD | CERAD_1: Vascular...    NaN       0.5
# 1     Harry's plaintext: CVD | CERAD_1: Vascular dis...    NaN       0.0
# 2     Harry's plaintext: Control | CERAD_1:  | CERAD...    1.0       0.5
# 3     Harry's plaintext: AD-Def. | CERAD_1: Definite...    4.0       0.5
# 4     Harry's plaintext: Control | CERAD_1:  | CERAD...    1.0       0.5
# ...                                                 ...    ...       ...
# 1243  Harry's plaintext: AD-Def. | CERAD_1: Definite...    4.0       4.0
# ...

# %%
clinical_data["Imaging_XENum"]
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3       XE92-153
# 4       XE05-040
#           ...
# 1695         NaN
# 1696         NaN
# 1697         NaN
# 1698         NaN
# 1699         NaN
# Name: Imaging_XENum, Length: 1700, dtype: object

# %%
img_data2.head(2)
# Out:
#                    FileName     XENum           BrainRegion         Stain  \
# 535  XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus  Amyloid Beta
# 576  XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus  Amyloid Beta
#
#      SeqNum    SentDate      BB  SubNum SubNum_with_M
# 535       1  12/21/2020  1383.0    4458         M4458
# 576       1  12/21/2020  1406.0   26772        M26772

# %%
clinical_data1 = pd.merge(clinical_data1, img_data2, left_on="SubID", right_on="SubNum_with_M", how="left")

# %%
clinical_data1.columns
# Out:
# Index(['SubID', 'Brain_bank', 'Dx', 'CERAD', 'CDRScore', 'Plq_Mn',
#        'Plq_Mn_MFG', 'AD', 'MCI', 'Dementia', 'PD', 'FileName', 'XENum',
#        'BrainRegion', 'Stain', 'SeqNum', 'SentDate', 'BB', 'SubNum',
#        'SubNum_with_M'],
#       dtype='object')

# %%
1271-1055
# Out:
# 216

# %%
wynton_files["Imaging_XENum"]=wynton_files["FileName"].apply(lambda l:l.split("_")[0])

# %%
wynton_files
# Out:
#                    FileName Imaging_XENum
# 0    XE17-013_1_AmyB_1.mrxs      XE17-013
# 1    XE18-001_7_AmyB_1.mrxs      XE18-001
# 2    XE17-029_1_AmyB_1.mrxs      XE17-029
# 3    XE11-039_1_AmyB_1.mrxs      XE11-039
# 4    XE18-003_1_AmyB_1.mrxs      XE18-003
# ..                      ...           ...
# 128  XE10-009_1_AmyB_1.mrxs      XE10-009
# 129  XE11-018_1_AmyB_1.mrxs      XE11-018
# 130  XE10-018_1_AmyB_1.mrxs      XE10-018
# 131  XE12-011_1_AmyB_1.mrxs      XE12-011
# 132  XE16-023_1_AmyB_1.mrxs      XE16-023
#
# [133 rows x 2 columns]

# %%
nonna_clinical_data = clinical_data[~clinical_data["Imaging_XENum"].isna()]

# %%
nonna_clinical_data
# Out:
#        SubID Brain_bank   Age     Sex Sex_chr_aneuploidy Ethnicity  \
# 3     M10001       MSSM  94.0  Female              False     White
# 4     M10031       MSSM  71.0    Male                NaN     White
# 6     M10247       MSSM  82.0    Male              False     White
# 7     M10282       MSSM  73.0    Male              False     White
# 8     M10361       MSSM  72.0    Male                NaN     White
# ...      ...        ...   ...     ...                ...       ...
# 1241   M9946       MSSM  93.0    Male                NaN     White
# 1244  M99877       MSSM  83.0    Male              False     Asian
# 1245  M99891       MSSM  68.0    Male              False     Black
# 1246  M99907       MSSM  45.0    Male                NaN     White
# 1247  M99926       MSSM  79.0  Female                NaN     White
#
#                                                      Dx    pH        PMI  \
# 3     Harry's plaintext: AD-Def. | CERAD_1: Definite...  6.00   2.750000
# ...

# %%
wynton_files[~wynton_files['Imaging_XENum'].isin(nonna_clinical_data['Imaging_XENum'])]
# Out:
#                    FileName Imaging_XENum
# 0    XE17-013_1_AmyB_1.mrxs      XE17-013
# 1    XE18-001_7_AmyB_1.mrxs      XE18-001
# 2    XE17-029_1_AmyB_1.mrxs      XE17-029
# 4    XE18-003_1_AmyB_1.mrxs      XE18-003
# 6    XE17-010_1_AmyB_1.mrxs      XE17-010
# 7    XE19-037_1_AmyB_1.mrxs      XE19-037
# 9    XE18-040_1_AmyB_1.mrxs      XE18-040
# 10   XE17-048_1_AmyB_1.mrxs      XE17-048
# 13   XE19-028_5_AmyB_1.mrxs      XE19-028
# 14   XE18-066_1_AmyB_1.mrxs      XE18-066
# 15   XE16-021_1_AmyB_1.mrxs      XE16-021
# 16   XE17-059_1_AmyB_1.mrxs      XE17-059
# 18   XE17-022_1_AmyB_1.mrxs      XE17-022
# 19   XE17-004_1_AmyB_1.mrxs      XE17-004
# 23   XE18-045_1_AmyB_1.mrxs      XE18-045
# 24   XE17-039_6_AmyB_1.mrxs      XE17-039
# 27   XE17-014_1_AmyB_1.mrxs      XE17-014
# 28   XE17-039_7_AmyB_1.mrxs      XE17-039
# 29   XE16-057_1_AmyB_1.mrxs      XE16-057
# 32   XE19-028_1_AmyB_1.mrxs      XE19-028
# 33   XE17-022_7_AmyB_1.mrxs      XE17-022
# ...

# %% [markdown]
# ## Update Clinical Metadata

# %%
clinical_data.head()
# Out:
#           SubID Brain_bank   Age     Sex Sex_chr_aneuploidy Ethnicity  \
# 0      M00_1061       MSSM  40.0    Male                NaN     Black
# 1      M00_1062       MSSM  60.0  Female                NaN  Hispanic
# 2  M00_BM444996       MSSM  66.0    Male              False     Black
# 3        M10001       MSSM  94.0  Female              False     White
# 4        M10031       MSSM  71.0    Male                NaN     White
#
#                                                   Dx    pH        PMI  \
# 0  Harry's plaintext: CVD+BPD | CERAD_1: Vascular...  6.87  11.333333
# 1  Harry's plaintext: CVD | CERAD_1: Vascular dis...  6.27   2.900000
# 2  Harry's plaintext: Control | CERAD_1:  | CERAD...  6.34  25.383333
# 3  Harry's plaintext: AD-Def. | CERAD_1: Definite...  6.00   2.750000
# 4  Harry's plaintext: Control | CERAD_1:  | CERAD...  7.31  21.616667
#
#   Death_Time  ...  LewyNucleusValue LewyLocusValue  LewyDorsalVValue  \
# ...

# %%
clinical_data1 = clinical_data[["SubID","Brain_bank","Age","Sex","Ethnicity","Dx","CERAD","CDRScore","Plq_Mn","Plq_Mn_MFG", "AD","MCI","Dementia","PD","prs_AD2"]]
clinical_data1 = clinical_data1[clinical_data1["Brain_bank"]=="MSSM"]

# %%
clinical_data = clinical_data[clinical_data["Brain_bank"]=="MSSM"]

# %%
permpanus = pd.read_excel("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/PermPanosNPS (1).xlsx")

# %%
permpanus.head(2)
# Out:
#    ID   BB  SubNum     XENum  HarryNP1 Additions
# 0   1  2.0   74831  XE86-004       2.0       NaN
# 1   2  4.0   48992  XE86-006       2.0       NaN

# %%
permpanus["SubNum_with_M"] = permpanus["SubNum"].apply(lambda l : "M"+str(l))

# %%
#img_clinical2 = pd.merge(img_data2,clinical_data1, left_on="SubNum_with_M", right_on="SubID", how="left")
img_clinical3 = pd.merge(clinical_data,permpanus,  left_on="SubID", right_on="SubNum_with_M",how="left")

# %%
img_clinical3.to_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/Clincal_metadata_updated_all_cols.csv")

# %%
img_clinical3["XENum"].isna().sum()
# Out:
# 3

# %%
img_clinical3[img_clinical3["XENum"]=="XE17-014"]
# Out:
# Empty DataFrame
# Columns: [SubID, Brain_bank, Age, Sex, Ethnicity, Dx, CERAD, CDRScore, Plq_Mn, Plq_Mn_MFG, AD, MCI, Dementia, PD, prs_AD2, ID, BB, SubNum, XENum, HarryNP1, Additions, SubNum_with_M]
# Index: []
#
# [0 rows x 22 columns]

# %%
img_clinical3.to_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/Clincal_metadata_updated_selected_cols.csv")

# %% [markdown]
# ## Other Checks

# %%
full_df[~full_df["XENum"].isin(img_clinical3["XENum_y"])]
# Out:
#      index                FileName     XENum           BrainRegion  \
# 76      76  XE10-009_1_AmyB_1.mrxs  XE10-009  Middle Frontal Gyrus
# 194     24  XE10-009_1_AmyB_1.mrxs  XE10-009  Middle Frontal Gyrus
#
#             Stain  SeqNum    SentDate    BB  SubNum   SubID Brain_bank   Age  \
# 76   Amyloid Beta       1  12/21/2020  1561   28710     NaN        NaN   NaN
# 194  Amyloid Beta       1         NaN  1561   28710  M28710       MSSM  82.0
#
#         Sex Ethnicity    key_1                         key_2 key_3
# 76      NaN       NaN      NaN                           NaN   NaN
# 194  Female     White  AD-Def.  Definite Alzheimer's disease   NaN

# %%
full_df
# Out:
#      index                FileName     XENum           BrainRegion  \
# 0        0  XE07-002_1_AmyB_1.mrxs  XE07-002  Middle Frontal Gyrus
# 1        1  XE07-027_1_AmyB_1.mrxs  XE07-027  Middle Frontal Gyrus
# 2        2  XE07-033_1_AmyB_1.mrxs  XE07-033  Middle Frontal Gyrus
# 3        3  XE07-034_1_AmyB_1.mrxs  XE07-034  Middle Frontal Gyrus
# 4        4  XE07-036_1_AmyB_1.mrxs  XE07-036  Middle Frontal Gyrus
# ..     ...                     ...       ...                   ...
# 206     49  XE12-031_1_AmyB_1.mrxs  XE12-031  Middle Frontal Gyrus
# 207     50  XE12-036_1_AmyB_1.mrxs  XE12-036  Middle Frontal Gyrus
# 208     53  XE13-003_1_AmyB_1.mrxs  XE13-003  Middle Frontal Gyrus
# 209     59  XE13-028_1_AmyB_1.mrxs  XE13-028  Middle Frontal Gyrus
# 210     62  XE14-033_1_AmyB_1.mrxs  XE14-033  Middle Frontal Gyrus
#
#             Stain  SeqNum    SentDate    BB  SubNum   SubID Brain_bank   Age  \
# 0    Amyloid Beta       1  12/21/2020  1383    4458     NaN        NaN   NaN
# ...

# %% [markdown]
# ## Match clinical with Wynton

# %%
wynton_files["XENum"]=wynton_files["FileName"].apply(lambda l:l.split("_")[0])

# %%
wynton_files[~wynton_files['XENum'].isin(img_clinical3['XENum'])]
# Out:
#                    FileName     XENum
# 2    XE17-029_1_AmyB_1.mrxs  XE17-029
# 6    XE17-010_1_AmyB_1.mrxs  XE17-010
# 7    XE19-037_1_AmyB_1.mrxs  XE19-037
# 13   XE19-028_5_AmyB_1.mrxs  XE19-028
# 19   XE17-004_1_AmyB_1.mrxs  XE17-004
# 27   XE17-014_1_AmyB_1.mrxs  XE17-014
# 32   XE19-028_1_AmyB_1.mrxs  XE19-028
# 60   XE17-029_7_AmyB_1.mrxs  XE17-029
# 78   XE17-014_6_AmyB_1.mrxs  XE17-014
# 128  XE10-009_1_AmyB_1.mrxs  XE10-009

# %%
wynton_files_match =  wynton_files[wynton_files['XENum'].isin(img_clinical3['XENum'])]

# %%
img_clinical3 = pd.merge(wynton_files_match, img_clinical3, on = "XENum",how="left")

# %%
img_clinical3.to_csv("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Metadata/AmyB/wynton_match_with_clinical.csv")

# %% [markdown]
# ## Copy to NAS

# %%
import os
import glob
import shutil
run_name_folder = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/reports/figures/distinctive-brook-32/"

# %%
len(glob.glob(os.path.join(run_name_folder, "*")))
# Out:
# 21

# %%
files = glob.glob(os.path.join(run_name_folder, "*"))

# %%
for f in files[1:]:
    run_name_f = os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/reports/figures/good-star-659/",f.split("/")[-1])
    if not os.path.exists(run_name_folder):
        os.makedirs(run_name_folder)
    shutil.copyfile(os.path.join(f,f.split("/")[-1] + "_quantify.csv"), os.path.join(run_name_f, f.split("/")[-1] + "_quantify.csv"))

# %%
if not os.path.exists(run_name_folder):
    os.makedirs(run_name_folder)

# %%
files[0]
# Out:
# '/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/reports/figures/distinctive-brook-32/XE12-016_1_AmyB_1'
