# %%
import os
import numpy as np
from PIL import Image 
import random
import glob

# %%
file_path = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test-patients/images/XE14-004_1_AmyB_1/*.png"
images = glob.glob(file_path)
random_image = random.choice(images)
print(random_image)

Image.open(random_image)
# Out:
# /gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test-patients/images/XE14-004_1_AmyB_1/x_43008_y_108544.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7F705655C0A0>

# %%
folders= glob.glob(os.path.join("/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test-images-annotation-pathologists","*"))

# %%
dirname = "/gladstone/finkbeiner/steve/work/data/npsad_data/vivek/Datasets/amyb_wsi/test-images-annotation-pathologists/"
for i, folder in enumerate(folders): 
    imgs = glob.glob(os.path.join(folder,"*.png"))
    folder = folder.split("/")[-1]
    print(folder)
    for filename in imgs:
        filename= filename.split("/")[-1]
        os.rename(dirname+"/"+folder+"/"+ filename, dirname+"/"+str(i)+"_"+filename)
# Out:
# XE17-059_1_AmyB_1
# XE14-004_1_AmyB_1
# XE13-007_1_AmyB_1
# XE12-010_1_AmyB_1
# XE09-063_1_AmyB_1
